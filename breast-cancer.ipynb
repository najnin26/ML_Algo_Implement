# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/kaggle/input/bcd30/BRCA.csv')
df
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 336           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 337           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 338           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 339           NaN   NaN     NaN       NaN       NaN       NaN       NaN
# 340           NaN   NaN     NaN       NaN       NaN       NaN       NaN
#
#     Tumour_Stage                      Histology ER status PR status  \
# ...

# %%
df.head(5)
# Out:
#      Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0  TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1  TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2  TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3  TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4  TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
#
#   Tumour_Stage                      Histology ER status PR status HER2 status  \
# 0          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 1           II             Mucinous Carcinoma  Positive  Positive    Negative
# 2          III  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 3           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
# 4           II  Infiltrating Ductal Carcinoma  Positive  Positive    Negative
#
#                   Surgery_type Date_of_Surgery Date_of_Last_Visit  \
# ...

# %%
df.isnull().sum()
# Out:
# Patient_ID             7
# Age                    7
# Gender                 7
# Protein1               7
# Protein2               7
# Protein3               7
# Protein4               7
# Tumour_Stage           7
# Histology              7
# ER status              7
# PR status              7
# HER2 status            7
# Surgery_type           7
# Date_of_Surgery        7
# Date_of_Last_Visit    24
# Patient_Status        20
# dtype: int64

# %%
df.shape
# Out:
# (341, 16)

# %%
#drop the null values
df.dropna(inplace=True)

# %%
df
# Out:
#        Patient_ID   Age  Gender  Protein1  Protein2  Protein3  Protein4  \
# 0    TCGA-D8-A1XD  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680
# 1    TCGA-EW-A1OX  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505
# 2    TCGA-A8-A079  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260
# 3    TCGA-D8-A1XR  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270
# 4    TCGA-BH-A0BF  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990
# ..            ...   ...     ...       ...       ...       ...       ...
# 329  TCGA-AN-A04A  36.0  FEMALE  0.231800   0.61804  -0.55779 -0.517350
# 330  TCGA-A8-A085  44.0    MALE  0.732720   1.11170  -0.26952 -0.354920
# 331  TCGA-A1-A0SG  61.0  FEMALE -0.719470   2.54850  -0.15024  0.339680
# 332  TCGA-A2-A0EU  79.0  FEMALE  0.479400   2.05590  -0.53136 -0.188480
# 333  TCGA-B6-A40B  76.0  FEMALE -0.244270   0.92556  -0.41823 -0.067848
#
#     Tumour_Stage                       Histology ER status PR status  \
# ...

# %%
df.shape
# Out:
# (317, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 317 entries, 0 to 333
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient_ID          317 non-null    object
#  1   Age                 317 non-null    float64
#  2   Gender              317 non-null    object
#  3   Protein1            317 non-null    float64
#  4   Protein2            317 non-null    float64
#  5   Protein3            317 non-null    float64
#  6   Protein4            317 non-null    float64
#  7   Tumour_Stage        317 non-null    object
#  8   Histology           317 non-null    object
#  9   ER status           317 non-null    object
#  10  PR status           317 non-null    object
#  11  HER2 status         317 non-null    object
#  12  Surgery_type        317 non-null    object
#  13  Date_of_Surgery     317 non-null    object
#  14  Date_of_Last_Visit  317 non-null    object
# ...

# %%
df.Gender.value_counts()#highly imbalanced dataset
# Out:
# Gender
# FEMALE    313
# MALE        4
# Name: count, dtype: int64

# %%
(df.Patient_Status.value_counts()*100)/len(df)#highly imbalanced dataset
# Out:
# Patient_Status
# Alive    80.44164
# Dead     19.55836
# Name: count, dtype: float64

# %%
Patient_Status=df['Patient_Status'].value_counts()
transactions=Patient_Status.index
quantity=Patient_Status.values
figure=px.pie( df,
    values=quantity,
    names=transactions,hole=0.40,
    title='Patient Status'
)
figure.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Protein1', 'Protein2', 'Protein3',
#        'Protein4', 'Tumour_Stage', 'Histology', 'ER status', 'PR status',
#        'HER2 status', 'Surgery_type', 'Date_of_Surgery', 'Date_of_Last_Visit',
#        'Patient_Status'],
#       dtype='object')

# %%
Tumour_Stage=df['Tumour_Stage'].value_counts()
transactions=Tumour_Stage.index
quantity=Tumour_Stage.values
figure=px.pie( df,
    values=quantity,
    names=transactions,hole=0.40,
    title='Tumour Stage'
)
figure.show()
# Out:
# <div>                            <div id="7f59c31f-2adb-4feb-8ac2-51f7d31f8a50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f59c31f-2adb-4feb-8ac2-51f7d31f8a50")) {                    Plotly.newPlot(                        "7f59c31f-2adb-4feb-8ac2-51f7d31f8a50",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["II","III","I"],"legendgroup":"","name":"","showlegend":true,"values":[180,77,60],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222
# ...

# %%
Histology=df['Histology'].value_counts()
transactions=Histology.index
quantity=Histology.values
figure=px.pie( df,
    values=quantity,
    names=transactions,hole=0.40,
    title='Histology'
)
figure.show()
# Out:
# <div>                            <div id="f4507ad6-38ad-4925-a589-713f01c293b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4507ad6-38ad-4925-a589-713f01c293b4")) {                    Plotly.newPlot(                        "f4507ad6-38ad-4925-a589-713f01c293b4",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Infiltrating Ductal Carcinoma","Infiltrating Lobular Carcinoma","Mucinous Carcinoma"],"legendgroup":"","name":"","showlegend":true,"values":[224,81,12],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},
# ...

# %%
ER_status=df['ER status'].value_counts()
transactions=ER_status.index
quantity=ER_status.values
figure=px.pie( df,
    values=quantity,
    names=transactions,hole=0.40,
    title='ER Status'
)
figure.show()
# Out:
# <div>                            <div id="de6f1045-933d-4024-a2e4-0886c891c312" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de6f1045-933d-4024-a2e4-0886c891c312")) {                    Plotly.newPlot(                        "de6f1045-933d-4024-a2e4-0886c891c312",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Positive"],"legendgroup":"","name":"","showlegend":true,"values":[317],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,
# ...

# %%
PR_status=df['PR status'].value_counts()
transactions=PR_status.index
quantity=PR_status.values
figure=px.pie( df,
    values=quantity,
    names=transactions,hole=0.40,
    title='PR Status'
)
figure.show()
# Out:
# <div>                            <div id="a2818e15-25dd-4ad0-b5ef-9b912241b908" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2818e15-25dd-4ad0-b5ef-9b912241b908")) {                    Plotly.newPlot(                        "a2818e15-25dd-4ad0-b5ef-9b912241b908",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Positive"],"legendgroup":"","name":"","showlegend":true,"values":[317],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,
# ...

# %%
HER2=df['HER2 status'].value_counts()
transactions=HER2.index
quantity=HER2.values
figure=px.pie( df,
    values=quantity,
    names=transactions,hole=0.40,
    title='HER2 Status'
)
figure.show()
# Out:
# <div>                            <div id="b85bf785-1dea-4c7f-933c-84a064d4324c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b85bf785-1dea-4c7f-933c-84a064d4324c")) {                    Plotly.newPlot(                        "b85bf785-1dea-4c7f-933c-84a064d4324c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Negative","Positive"],"legendgroup":"","name":"","showlegend":true,"values":[288,29],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222
# ...

# %%
df.drop(['Patient_ID','ER status', 'PR status','Date_of_Surgery', 'Date_of_Last_Visit'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Age  Gender  Protein1  Protein2  Protein3  Protein4 Tumour_Stage  \
# 0  36.0  FEMALE  0.080353   0.42638   0.54715  0.273680          III
# 1  43.0  FEMALE -0.420320   0.57807   0.61447 -0.031505           II
# 2  69.0  FEMALE  0.213980   1.31140  -0.32747 -0.234260          III
# 3  56.0  FEMALE  0.345090  -0.21147  -0.19304  0.124270           II
# 4  56.0  FEMALE  0.221550   1.90680   0.52045 -0.311990           II
#
#                        Histology HER2 status                 Surgery_type  \
# 0  Infiltrating Ductal Carcinoma    Negative  Modified Radical Mastectomy
# 1             Mucinous Carcinoma    Negative                   Lumpectomy
# 2  Infiltrating Ductal Carcinoma    Negative                        Other
# 3  Infiltrating Ductal Carcinoma    Negative  Modified Radical Mastectomy
# 4  Infiltrating Ductal Carcinoma    Negative                        Other
#
#   Patient_Status
# 0          Alive
# 1           Dead
# 2          Alive
# 3          Alive
# ...
